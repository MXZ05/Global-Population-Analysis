# %%
import pandas as pd

# %%
#Reading dataset
df = pd.read_csv('Population_dataset.csv', skiprows=4, quotechar='"')

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
df.shape
# Out:
# (266, 69)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
# Drop the column if it's specifically named 'Unnamed: 68'
df_cleaned = df.drop(columns=['Unnamed: 68'])

# %%
df_cleaned.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df = df_cleaned

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# 2023              1
# Length: 68, dtype: int64

# %%
df.fillna(method='bfill',axis=0,inplace=True)
# Out:
# C:\Users\zainz\AppData\Local\Temp\ipykernel_69976\1328914449.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',axis=0,inplace=True)

# %%
df.head(10)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
# 5                      Albania          ALB  Population, total    SP.POP.TOTL
# 6                      Andorra          AND  Population, total    SP.POP.TOTL
# 7                   Arab World          ARB  Population, total    SP.POP.TOTL
# 8         United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 9                    Argentina          ARG  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# ...

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# 2023              0
# Length: 68, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Bar Chart for the Top 20 Populations in 2020**

# %%
population_2020 = df[['Country Name','2020']].dropna()
population_2020 = population_2020.sort_values(by='2020',ascending=False).head(20)

# Convert population to billions
population_2020['2020'] = population_2020['2020'] / 1e9

population_2020
# Out:
#                                     Country Name      2020
# 259                                        World  7.856139
# 103                             IDA & IBRD total  6.667541
# 140                          Low & middle income  6.438170
# 156                                Middle income  5.758609
# 102                                    IBRD only  4.879367
# 62                    Early-demographic dividend  3.396051
# 139                          Lower middle income  2.966397
# 249                          Upper middle income  2.792212
# 63                           East Asia & Pacific  2.369439
# 142                    Late-demographic dividend  2.316785
# 61   East Asia & Pacific (excluding high income)  2.121866
# 230   East Asia & Pacific (IDA & IBRD countries)  2.095759
# 240                      South Asia (IDA & IBRD)  1.895144
# 204                                   South Asia  1.895144
# 104                                    IDA total  1.788174
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style

# Apply dark background style
style.use('dark_background')

# %%
plt.figure(figsize=(12,8))
plt.bar(population_2020['Country Name'],population_2020['2020'],color='lightcoral')
plt.title('Top 20 Populations in 2020',fontsize=16)
plt.xlabel('Country/Region/Class',fontsize=12)
plt.ylabel('Population in Billions',fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **LINE CHART OF POPULATION GROWTH**

# %%
# Select data for multiple countries and years
countries = ['China', 'India', 'Pakistan','United States']
population_trends = df[['Country Name'] + [str(year) for year in range(1960, 2024)]]

# Filter data for selected countries
population_trends = population_trends[population_trends['Country Name'].isin(countries)]

# Plot the line chart for each country
plt.figure(figsize=(10,6))

for country in countries:
    plt.plot(population_trends.columns[1:], population_trends[population_trends['Country Name'] == country].iloc[0,1:],label=country)

# Customize the chart
plt.title('Population Growth Trends (1960-2020)',fontsize=16)
plt.xlabel('Year',fontsize=14)
plt.ylabel('Population in Billions',fontsize=14)
plt.legend(title='Countries')
plt.xticks(ticks=range(0, len(population_trends.columns[1:]), 5), labels=population_trends.columns[1:][::5])
plt.tight_layout()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Histogram for Population Distribution**

# %%
plt.figure(figsize=(10,6))
plt.hist(population_2020['2020'], bins=15,color='lightcoral',edgecolor='black')
plt.title('Population Distribution Across Countries in 2020',fontsize=16)
plt.xlabel('Population',fontsize=12)
plt.ylabel('Number of Countries',fontsize=12)
plt.tight_layout()

plt.show()
